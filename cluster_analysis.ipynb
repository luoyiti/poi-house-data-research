# %% [markdown]
# # 聚类分析

# %%
import pandas as pd
import json

# %%
with open("data/house_poi_data_more_precise.json", "r") as f:
    data = json.load(f)
data[0]
# Out:
# {'id': 1,
#  'price_per_meter': '26641',
#  'lon': '116.480977',
#  'lat': '39.886406',
#  'pois': [{'id': 'node/1765216410',
#    'lat': 39.8842806,
#    'lon': 116.4833676,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': '窑洼湖桥北',
#     'name:zh': '窑洼湖桥北',
#     'public_transport': 'stop_position'},
#    'first_tag': 'public_transport',
#    'second_tag': 'stop_position'},
#   {'id': 'node/1765216482',
#    'lat': 39.8898846,
#    'lon': 116.4833507,
#    'tags': {'bus': 'yes',
#     'name': '大郊亭桥南',
#     'name:zh': '大郊亭桥南',
#     'public_transport': 'stop_position'},
#    'first_tag': 'public_transport',
#    'second_tag': 'stop_position'},
#   {'id': 'node/1765216484',
#    'lat': 39.8863172,
#    'lon': 116.4833521,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': '窑洼湖桥北',
#     'name:zh': '窑洼湖桥北',
#     'public_transport': 'stop_position'},
#    'first_tag': 'public_transport',
#    'second_tag': 'stop_position'},
# ...
